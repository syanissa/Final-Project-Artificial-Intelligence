# %% [markdown]
# # Install Libraries

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import joblib

# %% [markdown]
# # Functions

# %% [markdown]
# ## Extract Features

# %%
def extract_features_with_timing(file_path, start_time, end_time):
    audio, sample_rate = librosa.load(file_path, offset=start_time, duration=end_time - start_time, res_type='kaiser_fast')
    features = np.mean(librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40).T, axis=0)
    return features

# %% [markdown]
# ## Load and Save file

# %%
def label_audio_dataset_with_timing(dataset_path):
    data = []

    for class_label in os.listdir(dataset_path):
        class_path = os.path.join(dataset_path, class_label)

        if os.path.isdir(class_path):
            for audio_file in os.listdir(class_path):
                file_path = os.path.join(class_path, audio_file)

                # Check if the file is an audio file
                if audio_file.lower().endswith(('.wav', '.wm.wav')):
                    print(f"Processing: {file_path}")

                    # Form the correct text file name
                    text_file_name = f"{audio_file}.txt"
                    text_file_path = os.path.join(class_path, text_file_name)

                    if os.path.exists(text_file_path):
                        print(f"Found corresponding text file: {text_file_path}")

                        # Read all lines from the text file
                        with open(text_file_path, 'r') as f:
                            for line in f:
                                # Split the line into start and end times
                                start_time, end_time = map(float, line.split('\t'))

                                print(f"Start time: {start_time}, End time: {end_time}")

                                # Extract features for the specified time range
                                features = extract_features_with_timing(file_path, start_time, end_time)

                                data.append({
                                    'file_path': file_path,
                                    'features': features.tolist(),
                                    'class_label': class_label
                                })

                                print(f"Processed: {file_path}, Start: {start_time}, End: {end_time}\n")

                    else:
                        print(f"No corresponding text file found for: {file_path}. Using the entire duration.")

                        # Set start_time to 0 and end_time to the entire duration
                        start_time, end_time = 0, librosa.get_duration(filename=file_path)

                        print(f"Start time: {start_time}, End time: {end_time}")

                        # Extract features for the entire duration
                        features = extract_features_with_timing(file_path, start_time, end_time)

                        data.append({
                            'file_path': file_path,
                            'features': features.tolist(),
                            'class_label': class_label
                        })

                        print(f"Processed: {file_path}, Start: {start_time}, End: {end_time}\n")

    print(f"Number of samples in dataset: {len(data)}")
    return pd.DataFrame(data)

# %%
dataset_path = 'DATA_NIGENS'
labeled_data = label_audio_dataset_with_timing(dataset_path)
# Out:
# Processing: DATA_NIGENS\alarm\Alarm+8001_04.wav
# Found corresponding text file: DATA_NIGENS\alarm\Alarm+8001_04.wav.txt
# Start time: 0.024943, End time: 22.414966
# Processed: DATA_NIGENS\alarm\Alarm+8001_04.wav, Start: 0.024943, End: 22.414966
#
# Processing: DATA_NIGENS\alarm\Alarm+8001_04.wm.wav
# No corresponding text file found for: DATA_NIGENS\alarm\Alarm+8001_04.wm.wav. Using the entire duration.
# Start time: 0, End time: 1.8575510204081633
# Processed: DATA_NIGENS\alarm\Alarm+8001_04.wm.wav, Start: 0, End: 1.8575510204081633
#
# Processing: DATA_NIGENS\alarm\Alarm+8001_06.wav
# Found corresponding text file: DATA_NIGENS\alarm\Alarm+8001_06.wav.txt
# Start time: 0.038549, End time: 1.022676
# Processed: DATA_NIGENS\alarm\Alarm+8001_06.wav, Start: 0.038549, End: 1.022676
#
# Start time: 1.614512, End time: 2.659864
# Processed: DATA_NIGENS\alarm\Alarm+8001_06.wav, Start: 1.614512, End: 2.659864
#
# Start time: 3.190476, End time: 4.204082
# Processed: DATA_NIGENS\alarm\Alarm+8001_06.wav, Start:
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 11.564626, End: 11.807256
#
# Start time: 11.943311, End time: 12.199546
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 11.943311, End: 12.199546
#
# Start time: 12.351474, End time: 12.609977
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 12.351474, End: 12.609977
#
# Start time: 12.746032, End time: 13.002268
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 12.746032, End: 13.002268
#
# Start time: 13.154195, End time: 13.428571
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 13.154195, End: 13.428571
#
# Start time: 13.53288, End time: 13.791383
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 13.53288, End: 13.791383
#
# Start time: 13.956916, End time: 14.21542
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 13.956916, End: 14.21542
#
# Start time: 14.335601, End time: 14.594104
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 14.335601, End: 14.594104
#
# Start time: 14.746032, End time: 15.018141
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 14.746032, End: 15.018141
#
# Start time: 15.129252, End time: 15.249433
# Processed: DATA_NIGENS\alarm\Alarm+8005_18.wav, Start: 15.129252, End: 15.249433
#
# Processing: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav
# Found corresponding text file: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav.txt
# Start time: 0.018141, End time: 0.793651
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 0.018141, End: 0.793651
#
# Start time: 1.222222, End time: 1.981859
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 1.222222, End: 1.981859
#
# Start time: 2.426304, End time: 3.156463
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 2.426304, End: 3.156463
#
# Start time: 3.643991, End time: 4.403628
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 3.643991, End: 4.403628
#
# Start time: 4.848073, End time: 5.605442
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 4.848073, End: 5.605442
#
# Start time: 6.049887, End time: 6.825397
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 6.049887, End: 6.825397
#
# Start time: 7.269841, End time: 8.029478
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 7.269841, End: 8.029478
#
# Start time: 8.471655, End time: 9.247166
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 8.471655, End: 9.247166
#
# Start time: 9.69161, End time: 10.451247
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 9.69161, End: 10.451247
#
# Start time: 10.893424, End time: 11.668934
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 10.893424, End: 11.668934
#
# Start time: 12.113379, End time: 12.873016
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 12.113379, End: 12.873016
#
# Start time: 13.315193, End time: 14.090703
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 13.315193, End: 14.090703
#
# Start time: 14.535147, End time: 15.328798
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-MANY_6EXT8-10013.wav, Start: 14.535147, End: 15.328798
#
# Processing: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-SHORT_6EXT8-10015.wav
# Found corresponding text file: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-SHORT_6EXT8-10015.wav.txt
# Start time: 0.006803, End time: 0.768707
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC-BURST-SHORT_6EXT8-10015.wav, Start: 0.006803, End: 0.768707
#
# Processing: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00612.wav
# Found corresponding text file: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00612.wav.txt
# Start time: 0.120181, End time: 60.097506
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00612.wav, Start: 0.120181, End: 60.097506
#
# Processing: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00613.wav
# Found corresponding text file: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00613.wav.txt
# Start time: 0.238095, End time: 60.668934
# Processed: DATA_NIGENS\alarm\ALARM-ELECTRONIC_GEN-HDF-00613.wav, Start: 0.238095, End: 60.668934
#
# Processing: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav
# Found corresponding text file: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav.txt
# Start time: 0.031746, End time: 0.356009
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 0.031746, End: 0.356009
#
# Start time: 0.612245, End time: 1.002268
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 0.612245, End: 1.002268
#
# Start time: 1.231293, End time: 1.585034
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 1.231293, End: 1.585034
#
# Start time: 1.85941, End time: 2.192744
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 1.85941, End: 2.192744
#
# Start time: 2.478458, End time: 2.802721
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 2.478458, End: 2.802721
#
# Start time: 3.061224, End time: 3.412698
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 3.061224, End: 3.412698
#
# Start time: 3.689342, End time: 4.040816
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 3.689342, End: 4.040816
#
# Start time: 4.30839, End time: 4.698413
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 4.30839, End: 4.698413
#
# Start time: 4.907029, End time: 5.260771
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 4.907029, End: 5.260771
#
# Start time: 5.526077, End time: 5.879819
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 5.526077, End: 5.879819
#
# Start time: 6.126984, End time: 6.469388
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 6.126984, End: 6.469388
#
# Start time: 6.746032, End time: 7.088435
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 6.746032, End: 7.088435
#
# Start time: 7.365079, End time: 7.707483
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 7.365079, End: 7.707483
#
# Start time: 7.965986, End time: 8.326531
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 7.965986, End: 8.326531
#
# Start time: 8.585034, End time: 8.927438
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 8.585034, End: 8.927438
#
# Start time: 9.195011, End time: 9.369615
# Processed: DATA_NIGENS\alarm\alarm-sci+fi-constant_CAP01-13.wav, Start: 9.195011, End: 9.369615
#
# Processing: DATA_NIGENS\alarm\alarm-smoke+detector_CAP01-15.wav
# Found corresponding text file: DATA_NIGENS\alarm\alarm-smoke+detector_CAP01-15.wav.txt
# Start time: 0.002268, End time: 10.405896
# Processed: DATA_NIGENS\alarm\alarm-smoke+detector_CAP01-15.wav, Start: 0.002268, End: 10.405896
#
# Processing: DATA_NIGENS\alarm\AlarmAirplane+SUP01_02_3.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmAirplane+SUP01_02_3.wav.txt
# Start time: 0.002268, End time: 1.675737
# Processed: DATA_NIGENS\alarm\AlarmAirplane+SUP01_02_3.wav, Start: 0.002268, End: 1.675737
#
# Processing: DATA_NIGENS\alarm\AlarmBurglar+2013_42.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmBurglar+2013_42.wav.txt
# Start time: 0.174603, End time: 0.22449
# Processed: DATA_NIGENS\alarm\AlarmBurglar+2013_42.wav, Start: 0.174603, End: 0.22449
#
# Start time: 0.276644, End time: 54.058957
# Processed: DATA_NIGENS\alarm\AlarmBurglar+2013_42.wav, Start: 0.276644, End: 54.058957
#
# Processing: DATA_NIGENS\alarm\AlarmBurglar_DIGIF2-63.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmBurglar_DIGIF2-63.wav.txt
# Start time: 0.634921, End time: 30.0839
# Processed: DATA_NIGENS\alarm\AlarmBurglar_DIGIF2-63.wav, Start: 0.634921, End: 30.0839
#
# Processing: DATA_NIGENS\alarm\AlarmCar+PS01_06_2.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmCar+PS01_06_2.wav.txt
# Start time: 0.063492, End time: 30.21542
# Processed: DATA_NIGENS\alarm\AlarmCar+PS01_06_2.wav, Start: 0.063492, End: 30.21542
#
# Processing: DATA_NIGENS\alarm\AlarmDistress+6010_06.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmDistress+6010_06.wav.txt
# Start time: 0.038549, End time: 11.444444
# Processed: DATA_NIGENS\alarm\AlarmDistress+6010_06.wav, Start: 0.038549, End: 11.444444
#
# Processing: DATA_NIGENS\alarm\AlarmElectronic+6061_42.w
# Start time: 0.002268, End time: 9.941043
# Processed: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_09_1.wav, Start: 0.002268, End: 9.941043
#
# Processing: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_18_2.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_18_2.wav.txt
# Start time: 0.002268, End time: 10.14966
# Processed: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_18_2.wav, Start: 0.002268, End: 10.14966
#
# Processing: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_1.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_1.wav.txt
# Start time: 0.015873, End time: 11.544218
# Processed: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_1.wav, Start: 0.015873, End: 11.544218
#
# Processing: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_3.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_3.wav.txt
# Start time: 0.015873, End time: 12.172336
# Processed: DATA_NIGENS\alarm\AlarmElectronic+SFSE02_28_3.wav, Start: 0.015873, End: 12.172336
#
# Processing: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav.txt
# Start time: 0.015873, End time: 0.276644
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 0.015873, End: 0.276644
#
# Start time: 0.596372, End time: 0.888889
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 0.596372, End: 0.888889
#
# Start time: 1.628118, End time: 1.909297
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 1.628118, End: 1.909297
#
# Start time: 2.240363, End time: 2.496599
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 2.240363, End: 2.496599
#
# Start time: 4.015873, End time: 4.294785
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 4.015873, End: 4.294785
#
# Start time: 4.612245, End time: 4.907029
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 4.612245, End: 4.907029
#
# Start time: 5.678005, End time: 5.913832
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 5.678005, End: 5.913832
#
# Start time: 6.258503, End time: 6.562358
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 6.258503, End: 6.562358
#
# Start time: 8.063492, End time: 8.360544
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 8.063492, End: 8.360544
#
# Start time: 8.655329, End time: 8.961451
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 8.655329, End: 8.961451
#
# Start time: 9.70068, End time: 9.968254
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 9.70068, End: 9.968254
#
# Start time: 10.312925, End time: 10.591837
# Processed: DATA_NIGENS\alarm\AlarmElectronic_DIGIP02-89.wav, Start: 10.312925, End: 10.591837
#
# Processing: DATA_NIGENS\alarm\AlarmFire+2013_43.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmFire+2013_43.wav.txt
# Start time: 0.673469, End time: 60.791383
# Processed: DATA_NIGENS\alarm\AlarmFire+2013_43.wav, Start: 0.673469, End: 60.791383
#
# Processing: DATA_NIGENS\alarm\AlarmSmokeDetect+SUP01_02_7.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmSmokeDetect+SUP01_02_7.wav.txt
# Start time: 0.004535, End time: 0.909297
# Processed: DATA_NIGENS\alarm\AlarmSmokeDetect+SUP01_02_7.wav, Start: 0.004535, End: 0.909297
#
# Processing: DATA_NIGENS\alarm\AlarmSmokeDetector+6010_07.wav
# Found corresponding text file: DATA_NIGENS\alarm\AlarmSmokeDetector+6010_07.wav.txt
# Start time: 0.031746, End time: 28.9161
# Processed: DATA_NIGENS\alarm\AlarmSmokeDetector+6010_07.wav, Start: 0.031746, End: 28.9161
#
# Processing: DATA_NIGENS\alarm\Alarm_FactoryBuzzer_Loop_SFX-KIT.wav
# Found corresponding text file: DATA_NIGENS\alarm\Alarm_FactoryBuzzer_Loop_SFX-KIT.wav.txt
# Start time: 0.006803, End time: 1.412698
# Processed: DATA_NIGENS\alarm\Alarm_FactoryBuzzer_Loop_SFX-KIT.wav, Start: 0.006803, End: 1.412698
#
# Processing: DATA_NIGENS\alarm\AutoAlarm+CRB01_06_1.wav
# Found corresponding text file: DATA_NIGENS\alarm\AutoAlarm+CRB01_06_1.wav.txt
# Start time: 0.002268, End time: 16.176871
# Processed: DATA_NIGENS\alarm\AutoAlarm+CRB01_06_1.wav, Start: 0.002268, End: 16.176871
#
# Processing: DATA_NIGENS\alarm\BellAlarm_DIGIVJ2-60.wav
# Found corresponding text file: DATA_NIGENS\alarm\BellAlarm_DIGIVJ2-60.wav.txt
# Start time: 0.045351, End time: 5.605442
# Processed: DATA_NIGENS\alarm\BellAlarm_DIGIVJ2-60.wav, Start: 0.045351, End: 5.605442
#
# Processing: DATA_NIGENS\alarm\BoatAlarm+6025_66_1.wav
# Found corresponding text file: DATA_NIGENS\alarm\BoatAlarm+6025_66_1.wav.txt
# Start time: 0.176871, End time: 10.861678
# Processed: DATA_NIGENS\alarm\BoatAlarm+6025_66_1.wav, Start: 0.176871, End: 10.861678
#
# Processing: DATA_NIGENS\alarm\CartoonBell+4001_54_3.wav
# Found corresponding text file: DATA_NIGENS\alarm\CartoonBell+4001_54_3.wav.txt
# Start time: 0.773243, End time: 6.873016
# Processed: DATA_NIGENS\alarm\CartoonBell+4001_54_3.wav, Start: 0.773243, End: 6.873016
#
# Processing: DATA_NIGENS\alarm\CLOCK-ALARM_GEN-HDF-07559.wav
# Found corresponding text file: DATA_NIGENS\alarm\CLOCK-ALARM_GEN-HDF-07559.wav.txt
# Start time: 0.092971, End time: 0.44898
# Processed: DATA_NIGENS\alarm\CLOCK-ALARM_GEN-HDF-07559.wav, Start: 0.092971, End: 0.44898
#
# Start time: 0.591837, End time: 0.936508
# Processed: DATA_NIGENS\alarm\CLOCK-ALARM_GEN-HDF-07559.wav, Start:
#
# Start time: 0.646259, End time: 0.721088
# Processed: DATA_NIGENS\alarm\ClockAlarm+SUP01_41_1.wav, Start: 0.646259, End: 0.721088
#
# Start time: 0.780045, End time: 0.829932
# Processed: DATA_NIGENS\alarm\ClockAlarm+SUP01_41_1.wav, Start: 0.780045, End: 0.829932
#
# Start time: 0.895692, End time: 0.954649
# Processed: DATA_NIGENS\alarm\ClockAlarm+SUP01_41_1.wav, Start: 0.895692, End: 0.954649
#
# Processing: DATA_NIGENS\alarm\ClockAlarm+TL02_39.wav
# Found corresponding text file: DATA_NIGENS\alarm\ClockAlarm+TL02_39.wav.txt
# Start time: 0.011338, End time: 8.569161
# Processed: DATA_NIGENS\alarm\ClockAlarm+TL02_39.wav, Start: 0.011338, End: 8.569161
#
# Processing: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav
# Found corresponding text file: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav.txt
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1050
#   warnings.warn(
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1250
#   warnings.warn(
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1150
#   warnings.warn(
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=950
#   warnings.warn(
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1650
#   warnings.warn(
# c:\Users\Tasya\anaconda3\envs\Speech_Recognition\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1300
#   warnings.warn(
# Start time: 0.031746, End time: 1.888889
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav, Start: 0.031746, End: 1.888889
#
# Start time: 1.965986, End time: 3.868481
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav, Start: 1.965986, End: 3.868481
#
# Start time: 3.897959, End time: 5.761905
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav, Start: 3.897959, End: 5.761905
#
# Start time: 5.85034, End time: 7.705215
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav, Start: 5.85034, End: 7.705215
#
# Start time: 7.791383, End time: 9.648526
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF1_03_3.wav, Start: 7.791383, End: 9.648526
#
# Processing: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav
# Found corresponding text file: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav.txt
# Start time: 0.00907, End time: 0.29932
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 0.00907, End: 0.29932
#
# Start time: 0.510204, End time: 0.809524
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 0.510204, End: 0.809524
#
# Start time: 1.027211, End time: 1.294785
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 1.027211, End: 1.294785
#
# Start time: 1.514739, End time: 1.823129
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 1.514739, End: 1.823129
#
# Start time: 2.034014, End time: 2.340136
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 2.034014, End: 2.340136
#
# Start time: 2.55102, End time: 2.825397
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 2.55102, End: 2.825397
#
# Start time: 3.040816, End time: 3.346939
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 3.040816, End: 3.346939
#
# Start time: 3.557823, End time: 3.857143
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 3.557823, End: 3.857143
#
# Start time: 4.077098, End time: 4.342404
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 4.077098, End: 4.342404
#
# Start time: 4.571429, End time: 4.870748
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 4.571429, End: 4.870748
#
# Start time: 5.081633, End time: 5.367347
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 5.081633, End: 5.367347
#
# Start time: 5.600907, End time: 5.884354
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_15.wav, Start: 5.600907, End: 5.884354
#
# Processing: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav
# Found corresponding text file: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav.txt
# Start time: 0.06576, End time: 0.786848
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav, Start: 0.06576, End: 0.786848
#
# Start time: 1.297052, End time: 2.002268
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav, Start: 1.297052, End: 2.002268
#
# Start time: 2.421769, End time: 3.147392
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav, Start: 2.421769, End: 3.147392
#
# Start time: 3.560091, End time: 4.358277
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav, Start: 3.560091, End: 4.358277
#
# Start time: 4.800454, End time: 5.548753
# Processed: DATA_NIGENS\alarm\ElectronicAlarm+L2SF2_18.wav, Start: 4.800454, End: 5.548753
#
# Start time: 5.952381, End time: 6.736961
# ...
# Start time: 0.68254, End time: 14.764172
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 0.68254, End: 14.764172
#
# Start time: 15.444444, End time: 22.122449
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 15.444444, End: 22.122449
#
# Start time: 22.24263, End time: 29.664399
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 22.24263, End: 29.664399
#
# Start time: 30.283447, End time: 34.802721
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 30.283447, End: 34.802721
#
# Start time: 34.922902, End time: 38.68254
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 34.922902, End: 38.68254
#
# Start time: 38.843537, End time: 40.263039
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIB04-64.wav, Start: 38.843537, End: 40.263039
#
# Processing: DATA_NIGENS\piano\MusicPiano_DIGIVG1-76.wav
# Found corresponding text file: DATA_NIGENS\piano\MusicPiano_DIGIVG1-76.wav.txt
# Start time: 0.637188, End time: 195.403628
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIVG1-76.wav, Start: 0.637188, End: 195.403628
#
# Processing: DATA_NIGENS\piano\MusicPiano_DIGIVG1-77.wav
# Found corresponding text file: DATA_NIGENS\piano\MusicPiano_DIGIVG1-77.wav.txt
# Start time: 0.260771, End time: 1.376417
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIVG1-77.wav, Start: 0.260771, End: 1.376417
#
# Start time: 1.630385, End time: 53.444444
# Processed: DATA_NIGENS\piano\MusicPiano_DIGIVG1-77.wav, Start: 1.630385, End: 53.444444
#
# Processing: DATA_NIGENS\piano\Piano+2017_57_11.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_57_11.wav.txt
# Start time: 0.70068, End time: 5.011338
# Processed: DATA_NIGENS\piano\Piano+2017_57_11.wav, Start: 0.70068, End: 5.011338
#
# Processing: DATA_NIGENS\piano\Piano+2017_57_12.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_57_12.wav.txt
# Start time: 1.365079, End time: 6.081633
# Processed: DATA_NIGENS\piano\Piano+2017_57_12.wav, Start: 1.365079, End: 6.081633
#
# Start time: 6.328798, End time: 6.594104
# Processed: DATA_NIGENS\piano\Piano+2017_57_12.wav, Start: 6.328798, End: 6.594104
#
# Processing: DATA_NIGENS\piano\Piano+2017_57_13.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_57_13.wav.txt
# Start time: 0.655329, End time: 2.204082
# Processed: DATA_NIGENS\piano\Piano+2017_57_13.wav, Start: 0.655329, End: 2.204082
#
# Start time: 2.360544, End time: 2.591837
# Processed: DATA_NIGENS\piano\Piano+2017_57_13.wav, Start: 2.360544, End: 2.591837
#
# Start time: 2.736961, End time: 2.981859
# Processed: DATA_NIGENS\piano\Piano+2017_57_13.wav, Start: 2.736961, End: 2.981859
#
# Processing: DATA_NIGENS\piano\Piano+2017_57_5.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_57_5.wav.txt
# Start time: 0.37415, End time: 0.913832
# Processed: DATA_NIGENS\piano\Piano+2017_57_5.wav, Start: 0.37415, End: 0.913832
#
# Start time: 0.984127, End time: 5.179138
# Processed: DATA_NIGENS\piano\Piano+2017_57_5.wav, Start: 0.984127, End: 5.179138
#
# Processing: DATA_NIGENS\piano\Piano+2017_57_7.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_57_7.wav.txt
# Start time: 0.961451, End time: 3.183673
# Processed: DATA_NIGENS\piano\Piano+2017_57_7.wav, Start: 0.961451, End: 3.183673
#
# Start time: 3.272109, End time: 4.866213
# Processed: DATA_NIGENS\piano\Piano+2017_57_7.wav, Start: 3.272109, End: 4.866213
#
# Processing: DATA_NIGENS\piano\Piano+2017_58_10.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_58_10.wav.txt
# Start time: 0.875283, End time: 3.687075
# Processed: DATA_NIGENS\piano\Piano+2017_58_10.wav, Start: 0.875283, End: 3.687075
#
# Start time: 3.768707, End time: 5.721088
# Processed: DATA_NIGENS\piano\Piano+2017_58_10.wav, Start: 3.768707, End: 5.721088
#
# Start time: 5.918367, End time: 6.095238
# Processed: DATA_NIGENS\piano\Piano+2017_58_10.wav, Start: 5.918367, End: 6.095238
#
# Processing: DATA_NIGENS\piano\Piano+2017_58_2.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano+2017_58_2.wav.txt
# Start time: 0.614512, End time: 1.045351
# Processed: DATA_NIGENS\piano\Piano+2017_58_2.wav, Start: 0.614512, End: 1.045351
#
# Start time: 1.219955, End time: 1.671202
# Processed: DATA_NIGENS\piano\Piano+2017_58_2.wav, Start: 1.219955, End: 1.671202
#
# Start time: 1.993197, End time: 5.707483
# Processed: DATA_NIGENS\piano\Piano+2017_58_2.wav, Start: 1.993197, End: 5.707483
#
# Start time: 5.970522, End time: 6.566893
# Processed: DATA_NIGENS\piano\Piano+2017_58_2.wav, Start: 5.970522, End: 6.566893
#
# Start time: 6.873016, End time: 7.428571
# Processed: DATA_NIGENS\piano\Piano+2017_58_2.wav, Start: 6.873016, End: 7.428571
#
# Start time: 7.761905, End time: 8.142857
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav.txt
# Start time: 0.040816, End time: 0.587302
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav, Start: 0.040816, End: 0.587302
#
# Start time: 0.657596, End time: 0.789116
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav, Start: 0.657596, End: 0.789116
#
# Start time: 0.868481, End time: 1.045351
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav, Start: 0.868481, End: 1.045351
#
# Start time: 1.088435, End time: 1.54195
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_55_1.wav, Start: 1.088435, End: 1.54195
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_57_5.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_57_5.wav.txt
# Start time: 0.040816, End time: 6.278912
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_57_5.wav, Start: 0.040816, End: 6.278912
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_59_1.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_59_1.wav.txt
# Start time: 0.045351, End time: 4.786848
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_59_1.wav, Start: 0.045351, End: 4.786848
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav.txt
# Start time: 0.056689, End time: 2.333333
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 0.056689, End: 2.333333
#
# Start time: 2.609977, End time: 2.907029
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 2.609977, End: 2.907029
#
# Start time: 3.401361, End time: 3.639456
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 3.401361, End: 3.639456
#
# Start time: 3.693878, End time: 3.972789
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 3.693878, End: 3.972789
#
# Start time: 4.240363, End time: 4.492063
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 4.240363, End: 4.492063
#
# Start time: 4.582766, End time: 4.852608
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 4.582766, End: 4.852608
#
# Start time: 5.290249, End time: 6.630385
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_3.wav, Start: 5.290249, End: 6.630385
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_60_4.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_60_4.wav.txt
# Start time: 0.031746, End time: 6.814059
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_60_4.wav, Start: 0.031746, End: 6.814059
#
# Processing: DATA_NIGENS\piano\PianoComedy+CTE07_61_8.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy+CTE07_61_8.wav.txt
# Start time: 0.024943, End time: 0.306122
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_61_8.wav, Start: 0.024943, End: 0.306122
#
# Start time: 0.414966, End time: 1.131519
# Processed: DATA_NIGENS\piano\PianoComedy+CTE07_61_8.wav, Start: 0.414966, End: 1.131519
#
# Processing: DATA_NIGENS\piano\PianoComedy_DIGIP05-79.wav
# Found corresponding text file: DATA_NIGENS\piano\PianoComedy_DIGIP05-79.wav.txt
# Start time: 0.013605, End time: 2.922902
# Processed: DATA_NIGENS\piano\PianoComedy_DIGIP05-79.wav, Start: 0.013605, End: 2.922902
#
# Start time: 6.156463, End time: 9.614512
# Processed: DATA_NIGENS\piano\PianoComedy_DIGIP05-79.wav, Start: 6.156463, End: 9.614512
#
# Processing: DATA_NIGENS\piano\Piano_PlayScale_Up2_SFX-KIT.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano_PlayScale_Up2_SFX-KIT.wav.txt
# Start time: 0.00907, End time: 1.931973
# Processed: DATA_NIGENS\piano\Piano_PlayScale_Up2_SFX-KIT.wav, Start: 0.00907, End: 1.931973
#
# Processing: DATA_NIGENS\piano\Piano_PlayScale_UpDown1_SFX-KIT.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano_PlayScale_UpDown1_SFX-KIT.wav.txt
# Start time: 0.040816, End time: 3.272109
# Processed: DATA_NIGENS\piano\Piano_PlayScale_UpDown1_SFX-KIT.wav, Start: 0.040816, End: 3.272109
#
# Processing: DATA_NIGENS\piano\Piano_PlayScale_UpDown2_SFX-KIT.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano_PlayScale_UpDown2_SFX-KIT.wav.txt
# Start time: 0.013605, End time: 2.863946
# Processed: DATA_NIGENS\piano\Piano_PlayScale_UpDown2_SFX-KIT.wav, Start: 0.013605, End: 2.863946
#
# Processing: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav
# Found corresponding text file: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav.txt
# Start time: 0.011338, End time: 0.408163
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 0.011338, End: 0.408163
#
# Start time: 0.514739, End time: 0.900227
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 0.514739, End: 0.900227
#
# Start time: 1.0, End time: 1.451247
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 1.0, End: 1.451247
#
# Start time: 1.505669, End time: 1.85941
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 1.505669, End: 1.85941
#
# Start time: 1.941043, End time: 2.376417
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 1.941043, End: 2.376417
#
# Start time: 2.44898, End time: 2.687075
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 2.44898, End: 2.687075
#
# Start time: 2.793651, End time: 3.492063
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 2.793651, End: 3.492063
#
# Start time: 3.943311, End time: 4.163265
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 3.943311, End: 4.163265
#
# Start time: 4.294785, End time: 5.761905
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 4.294785, End: 5.761905
#
# Start time: 5.92517, End time: 6.376417
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 5.92517, End: 6.376417
#
# Start time: 6.498866, End time: 7.99093
# Processed: DATA_NIGENS\piano\Piano_PlaySong_RowBoat_SFX-KIT.wav, Start: 6.498866, End: 7.99093
#
# Processing: DATA_NIGENS\piano\PlayerPiano+1020_36_5.wav
# Found corresponding text file: DATA_NIGENS\piano\PlayerPiano+1020_36_5.wav.txt
# Start time: 1.269841, End time: 55.002268
# Processed: DATA_NIGENS\piano\PlayerPiano+1020_36_5.wav, Start: 1.269841, End: 55.002268
#
# Number of samples in dataset: 4166

# %% [markdown]
# # Split Dataset

# %%
train_data, test_data = train_test_split(labeled_data, test_size=0.2, train_size=0.8, random_state=42)

# %%
label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_data['class_label'])
test_labels = label_encoder.transform(test_data['class_label'])

# %%
X_train = np.array(train_data['features'].tolist())
X_test = np.array(test_data['features'].tolist())

# %% [markdown]
# # Modelling

# %%
model = keras.Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Reshape((X_train.shape[1], 1)),
    layers.Conv1D(64, kernel_size=3, activation='relu'),
    layers.MaxPooling1D(pool_size=2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(len(label_encoder.classes_), activation='softmax')
])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Training

# %%
# Train the model
model.fit(X_train, train_labels, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 84/84 [==============================] - 12s 22ms/step - loss: 1.9020 - accuracy: 0.6784 - val_loss: 0.7363 - val_accuracy: 0.8246
# Epoch 2/10
# 84/84 [==============================] - 1s 12ms/step - loss: 0.5801 - accuracy: 0.8251 - val_loss: 0.6901 - val_accuracy: 0.8186
# Epoch 3/10
# 84/84 [==============================] - 1s 11ms/step - loss: 0.4643 - accuracy: 0.8503 - val_loss: 0.5681 - val_accuracy: 0.8396
# Epoch 4/10
# 84/84 [==============================] - 1s 11ms/step - loss: 0.4129 - accuracy: 0.8668 - val_loss: 0.5636 - val_accuracy: 0.8261
# Epoch 5/10
# 84/84 [==============================] - 1s 16ms/step - loss: 0.3387 - accuracy: 0.8882 - val_loss: 0.5566 - val_accuracy: 0.8246
# Epoch 6/10
# 84/84 [==============================] - 1s 8ms/step - loss: 0.3000 - accuracy: 0.9028 - val_loss: 0.5247 - val_accuracy: 0.8456
# Epoch 7/10
# 84/84 [==============================] - 1s 10ms/step - loss: 0.2699 - accuracy: 0.9032 - val_loss: 0.5505 - val_accuracy: 0.8561
# Epoch 8/10
# 84/84 [==============================] - 1s 7ms/step - loss: 0.2725 - accuracy: 0.9107 - val_loss: 0.5731 - val_accuracy: 0.8486
# Epoch 9/10
# 84/84 [==============================] - 1s 14ms/step - loss: 0.2567 - accuracy: 0.9144 - val_loss: 0.4677 - val_accuracy: 0.8621
# Epoch 10/10
# 84/84 [==============================] - 1s 13ms/step - loss: 0.2316 - accuracy: 0.9220 - val_loss: 0.5501 - val_accuracy: 0.8636

# %% [markdown]
# # Evaluate

# %%
test_loss, test_accuracy = model.evaluate(X_test, test_labels)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8801
# Test Accuracy: 0.880095899105072

# %%
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)

predicted_class_labels = label_encoder.inverse_transform(predicted_labels)
# Out:
# 27/27 [==============================] - 1s 6ms/step

# %%
# Calculate accuracy on the test set
accuracy = accuracy_score(test_data['class_label'], predicted_class_labels)
print(f'Overall Test Accuracy: {accuracy}')
# Out:
# Overall Test Accuracy: 0.8800959232613909

# %% [markdown]
# # Save Model

# %%
# model.save('testModel.keras')
# joblib.dump(label_encoder, 'label_encoderTest.joblib')

# %% [markdown]
# # Predict Class

# %%
# Predict Class
def predict_calsses_for_audio(file_path, model_path, class_path):
    model = keras.models.load_model(model_path)
    label_encoder = LabelEncoder()
    label_encoder.classes_ = np.load(class_path, allow_pickle=True)

    #Ekstrak MFCC
    features = extract_features_with_timing(file_path, start_time=0, end_time=librosa.get_duration(path=file_path))
    features = features.reshape(1, -1)

    predictions = model.predict(features)

    total_duration = librosa.get_duration(path=file_path)
    class_percentages = {class_label: percentage * 100 for class_label, percentage in zip(label_encoder.classes_, predictions[0])}

    return class_percentages

# %%
audio_path = "DATA_NIGENS\engine\AMBULANCE_GEN-HDF-00814.wav"

model_path = "testModel.keras"
class_path = "label_encoderTest.joblib"
class_percentages = predict_calsses_for_audio(audio_path, model_path, class_path)

highest_class_label = None
highest_percentage = 0

for class_label, percentage in class_percentages.items():
    print(f"Class: {class_label}, Percentage: {percentage: .2f}%")

    if percentage > highest_percentage:
        highest_percentage = percentage
        highest_class_label = class_label
if highest_class_label:
    print(f"There is high  possibilities this is a {highest_class_label} sound with percentage {highest_percentage}%")
# Out:
# 1/1 [==============================] - 1s 1s/step
# Class: alarm, Percentage:  1.07%
# Class: baby, Percentage:  0.00%
# Class: crash, Percentage:  0.87%
# Class: dog, Percentage:  0.01%
# Class: engine, Percentage:  70.75%
# Class: femaleScream, Percentage:  0.00%
# Class: femaleSpeech, Percentage:  0.13%
# Class: fire, Percentage:  0.09%
# Class: footsteps, Percentage:  0.10%
# Class: general, Percentage:  20.48%
# Class: knock, Percentage:  4.55%
# Class: maleScream, Percentage:  0.00%
# Class: maleSpeech, Percentage:  0.04%
# Class: phone, Percentage:  0.00%
# Class: piano, Percentage:  1.90%
# There is high  possibilities this is a engine sound with percentage 70.74955701828003%
